# %%
# %load_ext nb_unittest
# Out:
# The nb_unittest extension is already loaded. To reload it, use:
#   %reload_ext nb_unittest

# %% [markdown]
# # Lab: Operators
#
# This lab will give you practice using operators to perform computation.

# %% [markdown]
# ## Part 1: Operators
#
# To answer the questions in this part your solution cells should *result* in the
# computation. For example, if the question asks you to compute the sum of `100`
# and `200` the solution cell should look like this:
#
# ```python
# """@celltag"""
#
# 100 + 200
# ```
#
# > Do not use the `print()` function. That will hide the answer from the checker.
# ### 1. Modulus
#
# Write a program that computes the value of `127` modulus `34`.

# %%
"""@mod"""
# Out:
# '@mod'

# %%
# %%testing @mod as solution
# import ast
# assert ast.Mod in solution.tokens, """I don't see the modulus operator"""
# assert {127, 34} < solution.constants, """I don't see one or more of the literals."""
# Out:
# <div style="font-size: large; font-weight: bold; margin-bottom: 0.5em; margin-top: 0.5em">
#     ⚠️ Attention needed.
# </div>
# <div>
#     I don&#39;t see the modulus operator
# </div>

# %% [markdown]
# ### 2. Multiply
#
# Write a program that multiplies `234.4` by `5`.

# %%
"""@mult"""
# Out:
# '@mult'

# %%
# %%testing @mult as solution
# import ast
# assert ast.Mult in solution.tokens, """I don't see the multiplication operator"""
# assert {234.4, 5} < solution.constants, """I don't see one or more of the literals."""
# Out:
# <div style="font-size: large; font-weight: bold; margin-bottom: 0.5em; margin-top: 0.5em">
#     ⚠️ Attention needed.
# </div>
# <div>
#     I don&#39;t see the multiplication operator
# </div>

# %% [markdown]
# ### 3. Compare Numbers
#
# Write a program that determines if `45.6` is less than `34.5`

# %%
"""@compa"""
# Out:
# '@compa'

# %%
# %%testing @compa as solution
# import ast
# assert ast.Lt in solution.tokens, """I don't see the less than operator"""
# assert {45,6, 34.5} < solution.constants, """I don't see one or more of the literals."""
# Out:
# <div style="font-size: large; font-weight: bold; margin-bottom: 0.5em; margin-top: 0.5em">
#     ⚠️ Attention needed.
# </div>
# <div>
#     I don&#39;t see the less than operator
# </div>

# %% [markdown]
# ### 4. Multiply and Compare
#
# Write a program that determines if `4.2` times `45` is less than or equal to `345.3`

# %%
"""@mulcomp"""
# Out:
# '@mulcomp'

# %%
# %%testing @mulcomp as solution
# import ast
# assert {ast.LtE, ast.Mult} < solution.tokens, """I don't see an operator that's necessary"""
# assert {4.2, 45, 345.3} < solution.constants, """I don't see one or more of the literals."""
# Out:
# <div style="font-size: large; font-weight: bold; margin-bottom: 0.5em; margin-top: 0.5em">
#     ⚠️ Attention needed.
# </div>
# <div>
#     I don&#39;t see an operator that&#39;s necessary
# </div>

# %% [markdown]
# ### 5. Days
#
# Write a program that computes how many days there are in 20 years.

# %%
"""@daysin20"""
# Out:
# '@daysin20'

# %%
# %%testing @daysin20 as solution
# import ast
# assert ast.Mult in solution.tokens, """I don't see the multiplication operator."""
# assert "print" not in solution.calls, """Don't use the print() function in this question."""
# assert solution.result.result is not None, """I don't see the result. Make sure your solution is on the last line."""
# assert solution.result.result >= 7300 and solution.result.result <= 7306, """I don't see the correct result."""
# Out:
# <div style="font-size: large; font-weight: bold; margin-bottom: 0.5em; margin-top: 0.5em">
#     ⚠️ Attention needed.
# </div>
# <div>
#     I don&#39;t see the multiplication operator.
# </div>

# %% [markdown]
# ### 6. Mileage
#
# Write a program that computes how far your car can go if it gets `34.5` miles per gallon and has a `11.5` gallon tank.

# %%
"""@mileage"""
# Out:
# '@mileage'

# %%
# %%testing @mileage as solution
# import ast
# assert ast.Mult in solution.tokens, """I don't see the multiplication operator."""
# assert "print" not in solution.calls, """Don't use the print() function in this question."""
# assert solution.result.result is not None, """I don't see the result. Make sure your solution is on the last line."""
# assert solution.result.result == 396.75, """I don't see the correct result."""
# Out:
# <div style="font-size: large; font-weight: bold; margin-bottom: 0.5em; margin-top: 0.5em">
#     ⚠️ Attention needed.
# </div>
# <div>
#     I don&#39;t see the multiplication operator.
# </div>

# %% [markdown]
# ### 7. How Much Gas
#
# Write a program that computes how much gas you need to go `200` miles if your car gets `34.5` miles per gallon.

# %%
"""@gallons"""
# Out:
# '@gallons'

# %%
# %%testing @gallons as solution
# import ast
# assert ast.Div in solution.tokens, """I don't see the division operator."""
# assert "print" not in solution.calls, """Don't use the print() function in this question."""
# assert solution.result.result is not None, """I don't see the result. Make sure your solution is on the last line."""
# assert solution.result.result.__class__ == float \
#     and round(solution.result.result,3) ==  5.797, """I don't see the correct result."""
# Out:
# <div style="font-size: large; font-weight: bold; margin-bottom: 0.5em; margin-top: 0.5em">
#     ⚠️ Attention needed.
# </div>
# <div>
#     I don&#39;t see the division operator.
# </div>

# %% [markdown]
# ### 8. A Lot of You
#
# Write a program that results in your name `100` times using the `*` operator.
#
# > Remember! Don't use `print`

# %%
"""@lots"""
# Out:
# '@lots'

# %%
# %%testing @lots as solution
# import ast
# assert ast.Mult in solution.tokens, """I don't see the multiplication operator."""
# assert "print" not in solution.calls, """Don't use the print() function in this question."""
# assert solution.result.result is not None, """I don't see the result. Make sure your solution is on the last line."""
# assert isinstance(solution.result.result, str) \
#     and len(solution.result.result) > 100, """There should be a lot of writing in the result."""
# Out:
# <div style="font-size: large; font-weight: bold; margin-bottom: 0.5em; margin-top: 0.5em">
#     ⚠️ Attention needed.
# </div>
# <div>
#     I don&#39;t see the multiplication operator.
# </div>

# %% [markdown]
# ### 9. Concatenation
#
# Write a program that concatenates three strings together using the `+` operator.

# %%
"""@cat"""
# Out:
# '@cat'

# %%
# %%testing @cat as solution
# import ast
# assert ast.Add in solution.tokens, """I don't see the addition operator."""
# assert len(solution.constants) == 4, """You should add three different strings."""
# assert "print" not in solution.calls, """Don't use the print() function in this question."""
# assert solution.result.result is not None, """I don't see the result. Make sure your solution is on the last line."""
# Out:
# <div style="font-size: large; font-weight: bold; margin-bottom: 0.5em; margin-top: 0.5em">
#     ⚠️ Attention needed.
# </div>
# <div>
#     I don&#39;t see the addition operator.
# </div>
