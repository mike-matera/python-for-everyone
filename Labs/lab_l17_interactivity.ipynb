# %%
# %load_ext nb_unittest
# %load_ext jupyter_turtle
import jupyter_turtle as tu 
from IPython.display import HTML

# %% [markdown]
# # Lab: Interactive Functions
#
# This lab has some simple user interfaces that will be completed by a function you write. Run the next cell before you begin:

# %%
import ipywidgets as widgets

# %% [markdown]
# ## Part 1: Interactive Functions
#
# Each of the following questions has code for a user interface (UI) and asks you to write a function.

# %% [markdown]
# ### 1. Add Integers
#
# Write an interactive function `add_ints` that takes two inputs, `a` and `b` and returns their sum.
#
# * Function name: `add_ints`
# * Arguments:
#   * `a` (`int`): The first int
#   * `b` (`int`): The second int
# * Returns: The sum of `a` and `b`

# %%
"""@add_func"""

# %%
# %%testing @add_func as cell, add_ints
#
# import ast
#
# assert "add_ints" in cell.functions, """I don't see the add_ints function in your solution."""
# assert "interact" in solution.functions["add_ints"].decorators, """I don't see the interact dectorator."""
# assert cell.functions["add_ints"].docstring is not None, """The add_ints() function should have a docstring"""
# assert ["a", "b"] == cell.functions["add_ints"].arguments, """add_ints doesn't seem to have the right arguments."""
# assert 2 == add_ints(1,1), """The add_ints() function didn't add 1 + 1"""
# assert 3 == add_ints(1,2), """The add_ints() function didn't add 1 + 2"""

# %% [markdown]
# ### 2. Hyperlink
#
# Write an interactive function named `hyper_link` that takes two inputs, `url` and `text` and returns an `HTML` containing a hyperlink that takes the browser to `url` and returns `text`.
#
# * Function name: `hyper_link`
# * Arguments:
#   * `url` (`str`): The link target
#   * `text` (`str`): The link text
# * Returns: An `HTML` with the hyperlink (it should be clickable).

# %%
"""@hyperl"""

# %%
# %%testing @hyperl as cell, hyper_link
#
# import ast
# from IPython.display import HTML
# assert "hyper_link" in cell.functions, """I don't see the hyper_link function in your solution."""
# assert "interact" in solution.functions["hyper_link"].decorators, """I don't see the interact dectorator."""
# assert cell.functions["hyper_link"].docstring is not None, """The hyper_link() function should have a docstring"""
# assert ["url", "text"] == cell.functions["hyper_link"].arguments, """hyper_link() doesn't seem to have the right arguments."""
# assert isinstance(hyper_link("foo", "bar"), HTML), """The hyper_link() function should return an HTML"""

# %% [markdown]
# ### 3. Interactive Drawing
#
# Write an interactive function that draws a triangle between 50 and 150 pixels.
#
# - Function name: `triangle`
# - Arguments:
#   - `size` (`int`): The size of the triangle
# - Returns: None

# %%
"""@draw_interaction"""

# %%
# %%testing @draw_interaction as solution, triangle
#
# assert "triangle" in solution.functions, """I don't see the definition of the triangle function."""
# assert "interact" in solution.functions["triangle"].decorators, """I don't see the interact dectorator."""
# assert ["size"] == solution.functions["triangle"].arguments, """The triangle function should have one argument, "size" """
# assert solution.result.turtle.stats["moves"] == 3, """Don't see three moves in the drawings."""
# assert {50, 150} < solution.constants, """I don't see 50 or 150 in your program's constants."""

# %% [markdown]
# ### 4. Interactive HTML
#
# Write an interactive function called `my_tag` that take two arguments, `tag`, the name of an HTML tag, and `contents`, some text to be put between the tags. The function should return an `HTML`. For example,
#
# ```
# >>> my_tag("b", "this is bold")
# HTML("<b>this is bold</b>")
# ```
# The function should be able to take any string in `tag` but use a pulldown to limit the function to just the `b`, `i` and `u` tags.
#
# - Function name: `my_tag`
# - Arguments:
#   - `my_tag` (`str`) - The type of the tag
#   - `contents` (`str`) - The text between the start and end tag
# - Returns: An HTML object

# %% [markdown]
# Make the function interactive in the next cell. Make the user choose between `"b"`, `"i"`, and `"u"` for the `tag` argument:

# %%
"""@html_interact"""

# %%
# %%testing @html_interact as solution
#
# assert "my_tag" in solution.functions, """I don't see the definition of the my_tag function."""
# assert "interact" in solution.functions["my_tag"].decorators, """I don't see the interact dectorator."""
# assert ["tag", "contents"] == solution.functions["my_tag"].arguments, """The my_tag function doesn't have the right arguments."""
# assert {"i", "b", "u"} <= solution.constants, """You should have the constants "i", "b", and "u" in your code."""
