# %% [markdown]
# # Wikipedia Helper
#
# In this project you will use a Python class to create an Appilcation Programming Interface (API) to help access Wikipedia. You can get programmatic data in the [JSON](https://en.wikipedia.org/wiki/JSON) format. JSON is easy to translate into Python dictionaries.
#
#
# ## The Wikipedia Class
#
# Your Wikipedia class should have the following definition:
#
# - Name: `Wikipedia`
# - Functions:
#   - `__init__` - The class initializer
#     - Arguments:
#       - `self`: The class instance
#       - `page`: The title of a page to access.
#   - `exists` - Returns `True` if the page exists, `False` otherwise.
#     - Arguments: `None`
#     - Returns: `True` or `False`
#   - `extract` - Return the extract of the page.
#     - Arguments: `None`
#     - Returns: The page extract as a string.
#
# ## Getting the Page Information
#
# Getting page information from Wikipedia is easy (if you know how to do it). The `wiki_fetch.py` program in Lesson11 shows you how. The program shows you the dictionary that's returned by Wikipedia. You should look at the output closely to learn the structure.
#
# The program takes an argument. Here's an example:
#
# ```
# $ python3 ./wiki_fetch.py 'Cabrillo College'
# {'batchcomplete': '',
#  'query': {'pages': {'1615527': {'extract': 'Cabrillo College is a public '
#                                             'community college offering '
#                                             'associate degrees and '
#                                             'certificates in more than 70 '
#                                             'fields of study. The college '
#                                             'itself is named after the '
#                                             'explorer Juan Rodríguez Cabrillo. '
#                                             'Its main campus is located in '
#                                             'Aptos, California and is situated '
#                                             'overlooking the Monterey Bay. It '
#                                             'is one of 115 public community '
#                                             'colleges in the state of '
#                                             'California. The college opened in '
#                                             '1959. Cabrillo College has an '
#                                             'enrollment of about 12,000 '
#                                             'students per term.',
#                                  'ns': 0,
#                                  'pageid': 1615527,
#                                  'title': 'Cabrillo College'}}}}
# ```
#
# Your program should reuse the `get_wikipage()` function in `wiki_fetch.py`. It's okay to copy-and-paste it directly into your program.
#
# ## Requirements
#
# Your program must meet the following requirements:
#
# - Your code must be in a file called `wikipedia.py`
# - You must have a docstring in your file.
# - You must have a class called `Wikipedia`
#   - The `Wikipedia` class must have a docstring
# - Your class must have the required functions
#   - The functions must have a docstring
#
# ## Turn In
#
# Turn in your Lesson11 directory that contains your `wikipedia.py` file.
