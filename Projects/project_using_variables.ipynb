# %% [markdown]
# # Using Variables
#
# In this project you'll create a program that uses variable to parameterize the execution of code.
#
# ## Lesson Exercises
#
# The exercises in this lesson must be turned in. They're important practice and will help you with the project.
#
# ## A Simple Calculation
#
# According to Wikipedia the average solar year is
#
#  * 365 days
#  * 5 hours
#  * 48 minutes
#  * 45 seconds
#
# Write a program that calculates the number of seconds in a mean solar year and prints the calculation. Start by storing each of the days, hours, minutes and seconds in a variable. Like this:
#
# ```python
# days = 365
# hours = 5
# ```
#
# Name your program `using_variables.py` I will run it like this:
#
# ```bash
# $ python3.6 ./using_variables.py
# There are exactly 31556925 seconds in a solar year.
# ```
#
# Your program should produce output that looks exactly like mine. Be precise!
#
# ## Requirements
#
#  * All Python files must have a properly formatted docstring
#  * Submit your program in a file called `using_variables.py`
#  * Your program must print only one number, the number of seconds in a solar year
#  * You can print any other words you want
#  * **DO NOT** print any other numbers!
#
# ## Turn In
#
# You must turn in the following files:
#
#  * using_variables.py
#
# The file should be zipped inside of the `Lesson02` directory and submitted with your completed practice notebooks.

# %% [markdown]
# ## Testing Your Project
#
# The cell below contains a test case that will test if your project meets requirements. Before you submit your assignment run the cell and make sure there are no errors.

# %%
import re
import pexpect
from p4e.testlib import TestCase, run

class TestUsingVariables(TestCase):

    test_file = 'using_variables.py'
       
    def test_01_for_docstring(self):
        """Looking for the docstring"""
        self.check_docstring(regex=r'(?i)cis-15')
        
    def test_02_check_output(self):        
        """Looking for the right number in the output of your program."""
        with self.spawn() as test:
            test.expect("31556925")

    def test_03_check_hardcode(self):
        """Making sure the result number is not hard-coded."""
        with open(self.test_file) as py:
            for i,l in enumerate(py):
                if re.search(r'31556925', l) is not None:
                    if re.search(r'#', l) is None:
                        self.fail(f'Suspicious line {i+1}: The number 31556925 in your code.')


run()
# Out:
# <h3>Test Results</h3>
#
# <style>
# .grid-container {
#   display: grid;
#   grid-template-columns: 7em auto;
#   grid-gap: 10px;
# }
# .grid-item-icon {
# 	text-align: center;
# }
# .grid-item {
# 	text-align: left;
# }
#
# </style>
#
#
#
# <div class="grid-container">
# 	<div class="grid-item-icon">
# 	<div class="alert alert-success">
# 		<strong>PASS</strong>
# 	  </div>
# </div>
# <div class="grid-item">
# 	<b>test_01_for_docstring</b><br>
# 	<i>Looking for the docstring</i>
# </div>
#
#
# 	<div class="grid-item-icon">
# 	<div class="alert alert-success">
# 		<strong>PASS</strong>
# 	  </div>
# </div>
# <div class="grid-item">
# 	<b>test_03_check_hardcode</b><br>
# 	<i>Making sure the result number is not hard-coded.</i>
# </div>
#
#
# 	<div class="grid-item-icon">
# 	<div class="alert alert-danger">
# 		<strong>FAIL</strong>
# 	  </div>
# </div>
# <div class="grid-item">
# 	<b>test_02_check_output</b><br>
# 	<i>Looking for the right number in the output of your program.</i>
# </div>
#
# 	<div class="grid-item"></div>
# 	<div class="grid-item">
# 		<pre>Traceback (most recent call last):
#   File "/home/maximus/lifealgorithmic-web/source/content/python-for-everyone/p4e/testlib.py", line 147, in spawn
#     yield spawn
#   File "<ipython-input-1-324dd849b474>", line 16, in test_02_check_output
#     test.expect("31556925")
#   File "/home/maximus/lifealgorithmic-web/source/content/python-for-everyone/p4e/testlib.py", line 141, in expect
#     super().expect(*args, **kwargs)
# pexpect.exceptions.EOF: End Of File (EOF). Exception style platform.
# <p4e.testlib.TestCase.spawn.<locals>.SpawnWrapper object at 0x7f2ac81c5550>
# command: /home/maximus/lifealgorithmic-web/source/content/python-for-everyone/venv-cis-15/bin/python3
# args: [b'/home/maximus/lifealgorithmic-web/source/content/python-for-everyone/venv-cis-15/bin/python3', b'/home/maximus/lifealgorithmic-web/source/content/python-for-everyone/Projects/using_variables.py']
# buffer (last 100 chars): ''
# before (last 100 chars): 'There are this many seconds:\r\n31556926\r\n'
# after: <class 'pexpect.exceptions.EOF'>
# match: None
# match_index: None
# exitstatus: None
# flag_eof: True
# pid: 28125
# child_fd: 59
# closed: False
# timeout: 2.0
# delimiter: <class 'pexpect.exceptions.EOF'>
# logfile: <_io.StringIO object at 0x7f2ac81ad558>
# logfile_read: None
# logfile_send: None
# maxread: 2000
# ignorecase: False
# searchwindowsize: None
# delaybeforesend: 0.05
# delayafterclose: 0.1
# delayafterterminate: 0.1
# searcher: searcher_re:
#     0: re.compile('31556925')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<ipython-input-1-324dd849b474>", line 16, in test_02_check_output
#     test.expect("31556925")
#   File "/usr/lib/python3.6/contextlib.py", line 99, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "/home/maximus/lifealgorithmic-web/source/content/python-for-everyone/p4e/testlib.py", line 150, in spawn
#     self.fail(f"""I expected to see one of [{','.join(spawn.what)}] from your program.""")
# AssertionError: I expected to see one of [31556925] from your program.
#
# Stdout:
# There are this many seconds:
# 31556926
# </pre>
# 	</div>
#
#
#
#
# </div>
